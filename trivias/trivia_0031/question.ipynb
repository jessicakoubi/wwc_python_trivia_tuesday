# %% [markdown]
# # Question
#
# ## What is the output of the following code ?

# %%
from thefuzz import process

l = [
    "Grace Hopper", 
    "Ada Lovelace", 
    "Margaret Hamilton", 
    "Karen Spärck Jones", 
    "Katherine Johnson",
    ]

r = process.extractOne("A. Lovelace", l, score_cutoff=80)
print(r)

# %% [markdown]
# ## Answers
#
# * a) A. Lovelace
# * b) Lovelace
# * c) A
# * d) ('Ada Lovelace', 87)
